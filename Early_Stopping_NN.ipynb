# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.datasets import make_circles
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
# model = Sequential()
# model.add(Dense(256, input_dim=2, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))

# %%
model=Sequential([
    Dense(units=256,activation='relu'),
    Dense(units=1,activation='sigmoid')
    ])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callbacks=EarlyStopping(patience=5)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4852 - accuracy: 0.8625 - val_loss: 0.6322 - val_accuracy: 0.5500
# Epoch 2/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4838 - accuracy: 0.8625 - val_loss: 0.6310 - val_accuracy: 0.5500
# Epoch 3/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4820 - accuracy: 0.8625 - val_loss: 0.6285 - val_accuracy: 0.5500
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4808 - accuracy: 0.8625 - val_loss: 0.6260 - val_accuracy: 0.5500
# Epoch 5/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4801 - accuracy: 0.8625 - val_loss: 0.6226 - val_accuracy: 0.6000
# Epoch 6/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4786 - accuracy: 0.8625 - val_loss: 0.6207 - val_accuracy: 0.6000
# Epoch 7/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4772 - accuracy: 0.8625 - val_loss: 0.6193 - val_accuracy: 0.6500
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4759 - accuracy: 0.8625 - val_loss: 0.6198 - val_accuracy: 0.6500
# Epoch 9/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4748 - accuracy: 0.8625 - val_loss: 0.6195 - val_accuracy: 0.6500
# Epoch 10/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.4737 - accuracy: 0.8625 - val_loss: 0.6208 - val_accuracy: 0.5500
# Epoch 11/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4724 - accuracy: 0.8500 - val_loss: 0.6209 - val_accuracy: 0.5500
# Epoch 12/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4717 - accuracy: 0.8500 - val_loss: 0.6219 - val_accuracy: 0.5500

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 15s 2ms/step
